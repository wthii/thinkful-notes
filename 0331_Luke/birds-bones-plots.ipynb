# %%
import pandas as pd

# %%
df = pd.read_csv('birds-bones-and-living-habits.zip')

# %%
# I really should set column 'id' to be the index...

# %%
df.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.lmplot(x='huml', y='feml', hue='type', data=df, fit_reg=False)

# %%
df.groupby('type').describe().drop('id',axis=1)
# Out:
#                   feml        femw        huml        humw        tarl  \
# type
# P    count   38.000000   38.000000   38.000000   38.000000   38.000000
#      mean    28.217368    2.307895   34.423947    3.039211   25.787368
#      std     10.613094    0.803836    9.399708    0.631918   14.836621
#      min     16.270000    1.210000    9.850000    1.730000    7.770000
#      25%     20.640000    1.980000   28.697500    2.660000   15.822500
#      50%     25.400000    2.135000   33.800000    2.930000   21.895000
#      75%     31.857500    2.505000   42.305000    3.492500   30.540000
#      max     54.670000    4.250000   49.120000    4.640000   63.910000
# R    count   50.000000   50.000000   50.000000   50.000000   49.000000
#      mean    62.020000    5.266800   86.934400    6.065600   59.166327
#      std     18.071290    1.859652   31.715294    2.170025   19.094756
#      min     27.460000    2.190000   33.120000    2.400000   19.100000
# ...

# %%
df.boxplot(by='type')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1073f76a0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10781a978>]], dtype=object)

# %%
# above was forced to the same y-axis which is not good...
# seaborne is 'smarter' than matplotlib alone ...

# %%
sns.pairplot(df, hue="type")

# %%
# the above is a more general version of lmplot
# it looks nice ... the axis were set 'well'

# %%
sns.PairGrid(df, hue="type",diag_sharey=False)
# somehting is wrong here ... not sure....
