# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('mtcars.csv')

# %%
df['mpg'].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
df.boxplot(column="mpg", return_type='axes')

# %%
df.groupby('mpg')['hp'].mean()
# Out:
# mpg
# 10.4    210.0
# 13.3    245.0
# 14.3    245.0
# 14.7    230.0
# 15.0    335.0
# 15.2    165.0
# 15.5    150.0
# 15.8    264.0
# 16.4    180.0
# 17.3    180.0
# 17.8    123.0
# 18.1    105.0
# 18.7    175.0
# 19.2    149.0
# 19.7    175.0
# 21.0    110.0
# 21.4    109.5
# 21.5     97.0
# 22.8     94.0
# 24.4     62.0
# 26.0     91.0
# 27.3     66.0
# 30.4     82.5
# 32.4     66.0
# 33.9     65.0
# Name: hp, dtype: float64

# %%
df.groupby('mpg')['hp'].mean().plot()
